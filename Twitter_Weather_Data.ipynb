# %%
import tweepy
from tweepy import OAuthHandler
from tweepy import Stream
from tweepy.streaming import StreamListener
import csv
 
consumer_key = 'Psk5HoEmUzz5hyDBHuINC2THE'
consumer_secret = 'qMI0HFt4eBnlkJ8Z6rIw78Qz3tP7hJLkcSaezZGGl7WtPyzWnq'
access_token = '1046554892582641664-dUzZBDJkyarT4l9DgCOzagkuDctDxB'
access_secret = 'ESAt0Xe4KI4dF3w5LYC54Xim1Meh7tzjpgMupn4uDj2dR'
 
auth = OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_secret)
 
api = tweepy.API(auth,wait_on_rate_limit=True, wait_on_rate_limit_notify=True)
print(api.rate_limit_status()['resources']['search'])

csvFile = open('/Users/bhavanirishitharavipati/Desktop/Big Data Analytics/ua.csv', 'a')
#Use csv Writer
csvWriter = csv.writer(csvFile)
print('hi')
for tweet in tweepy.Cursor(api.search,q="#rocky",count=100,
                           lang="en",
                           since="2018-04-03").items():
    print('hi')
    print (tweet.created_at, tweet.text)
    csvWriter.writerow([tweet.created_at, tweet.text])
# Out:
# {'/search/tweets': {'limit': 180, 'remaining': 180, 'reset': 1553552519}}
# hi
# hi
# 2019-03-25 21:50:56 RT @KpopMeEnt: #LA &amp; #SF here is the show day schedule❣️
#
# #ASTRO #ASTROinUSA #MJ #JINJIN #CHAEUNWOO #MOONBIN #ROCKY #YOONSANHA #KPOPME #AST…
# hi
# 2019-03-25 21:46:29 RT @EditsGk: David ‘Rocky’ Rocastle
# 2/5/67 - 31/3/01
# Never Forgotten 🙏❤️
# @Arsenal Legend 💯
# #Rocky #WeAreTheArsenal https://t.co/Z6mCoeVPUF
# hi
# 2019-03-25 21:37:08 RT @linagarcia_0417: MJ is so adorable 🙊💓
#
# #astroinusa
# #ASTROinLA
# #chaeunwoo #moonbin
# #yoonsanha #jinjin
# #mj #rocky
# #AROHA #아로하
# #아스트로
# #AST…
# hi
# 2019-03-25 21:18:24 RT @offclatsro: 190321 #astroindallas #astroadindallas #astro #아스트로 #rocky #sanha #moonbin #라키 #문빈 #산하 #윤산하 #ラキ #ムンビン #ユンサナ
#
# These three re…
# hi
# 2019-03-25 20:54:07 @offclASTRO i can't believe its #astro #Rocky who tweet this....
# so childish but so cute...
# can't help but smile...😊😊😊😊😊
# hi
# ...

# %%
import urllib3
from bs4 import BeautifulSoup
import json

d = '2019-01-13'
url = 'http://api.worldweatheronline.com/premium/v1/past-weather.ashx?key=25317f03245a4c30ae0233528192703&q=London&format=json&date='+d

http = urllib3.PoolManager()
response = http.request('GET', url)
soup = BeautifulSoup(response.data)
newDictionary=json.loads(soup.text)
#print(newDictionary['data']['weather'][0])
maxTemp = newDictionary['data']['weather'][0]['maxtempC']
minTemp = newDictionary['data']['weather'][0]['mintempC']
print(minTemp,maxTemp)
# Out:
# 10 12

# %%
import urllib3
from bs4 import BeautifulSoup
import json

#d = '2019-01-13'
url = 'https://api.opencagedata.com/geocode/v1/json?q=Rocky%20Mountain%20National%20Park&key=bf2ca7ffcfe54f29b3a05fa4bcd5a06f'
#url = 'https://api.opencagedata.com/geocode/v1/json?q=Rua+Cafel%C3%A2ndia%2C+Carapicu%C3%ADba%2C+Brasil&key=bf2ca7ffcfe54f29b3a05fa4bcd5a06f&pretty=1'
http = urllib3.PoolManager()
response = http.request('GET', url)
soup = BeautifulSoup(response.data)
newDictionary=json.loads(soup.text)
lat = newDictionary["results"][0]['geometry']['lat']
lng = newDictionary["results"][0]['geometry']['lng']
print('lat',lat)
print('lng',lng)
# Out:
# /Users/bhavanirishitharavipati/anaconda3/lib/python3.7/site-packages/urllib3/connectionpool.py:847: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)
# lat 40.3333178
# lng -105.7088953
