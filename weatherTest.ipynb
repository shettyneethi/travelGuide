# %%
import urllib3
from bs4 import BeautifulSoup
import json
places = [
"Colorado%20National%20Monument",
"History%20Colorado%20Center",
"Colorado%20Provencal",
"Colrado%20Convention%20Center",
"Colorado%20State%20Capital",
"Cripple%20Creek & Victor%20Narrow%20Guage%20Railroad",
"Cumbres%20Creek & Toltec%20Scenic%20Railroad",
"Georgetown%20Loop%20Historic%20Railroad",
"Rio%20Grande%20Scenic%20Railroad",
"Tiny%20Town",
"Leadville, Colorado & Southern%20Railroad",
"Durango%20and%20Silverton%20Railroad",
"Carousel%20of%20Happiness",
"Cave%20of%20the%20Winds%20Mountain%20Park",

"Glenwood%20Caverns%20Adventure%20Park",
"Colorado%20Adventure%20Park",
"Estes%20Park",
"Emerald%20Lake%20Trail",
"Hanging%20Lake%20Trail",
"Maroon%20Lake%20Scenic%20Trail",
"Yankee%20Boy%20Basin",
"Pikes%20Peak",
"Manitou%20Springs%20Incline",
"Rio%20Grande%20Trail",
"Piedra%20River%20Trail",
"Bear%20Creek%20Falls",
"Roxborough%20State%20Park",
"McCullough%20Gulch",
"St. Mary's%20Glacier",
"Yampa%20River%20Core%20Trail",
"Petroglyph%20Point",
"Horsetooth%20Mountain",
"Perimeter%20Trail",
"Booth%20Falls%20Trail",
"Bear%20Lake%20Trailhead",
"Animas%20River%20Trail",
"Devil's%20Backbone%20Nature%20Trail",
"Tunnel%20Drive",
"Seven%20Bridges%20Trail",
"Crater%20Lake%20Trail",
"Lower%20Cascade%20Trail%20and%20Falls",
"Adams%20Falls%20Trail",
"Palmer%20Park",
"Last%20Dollar%20Road",
"Mount%20Sanitas%20Trail",
"Canyon%20View%20Park",
"Ice%20Lakes%20Trail",
"Black%20Canyon%20of%20the%20Gunnison%20National%20Park",
"San%20Juan%20National%20Forest",
"Great%20Sand%20Dunes%20National%20Park",
"Gunnison%20National%20Forest",
"Hovenweep%20National%20Monument",
"Curecanti%20National%20Recreation%20Area",
"Florissant%20Fossil%20Beds%20National%20Monument",
"San%20Isabel%20National%20Forest",
"Mesa%20Verde%20National%20Park",
"High%20Dune%20Trail",
"North%20Rim",
"Pike%20National%20Forest",
"Summit%20Lake%20Park",
"Many Parks Curve",
"Maroon%20Bells",
"Mount%20Evans",
"Rocky%20Mountains",
 "Mount%20Elbert",
"Grand%20Mesa",
"Flagstaff%20Mountain",
"Aspen%20Mountain / Ajax",
"Lookout%20Mountain",
"Buttermilk%20Mountain",
"Peak%209",
"Vail%20Mountain%20Resort",
"Cheyenne%20Mountain",
"Peak%2010",
"Winter%20Park%20Resort",
"Rabbit%20Mountain",
"Longs%20Peak",
"Silverton%20Mountain",
"Epic%20Discovery%20at%20Breck",
"Mayflower%20Gulch",
"Deer%20Mountain",
"Many%20Parks%20Curve%20Overlook",
"William%20F. Hayden%20Green%20Mountain%20Park",
"Alluvial%20Fan",
"North%20Clear%20Creek%20Falls",
"Rock%20Park",
"Painted%20Wall",
"Square%20Tower%20House",
"Flatirons",
"Yankee%20Boy%20Basin",
"Roxborough%20State%20Park",
"Red%20Rock%20Canyon",
"Bachelor%20Loop",
"North%20Cheyenne%20Canon%20Park%20and%20Starsmore%20Discovery%20Center",
"Colorado%20Wolf%20and%20Wildlife%20Center",
"Blue%20Mesa%20Fishing",
"Butterfly%20Pavilion%20and%20Insect%20Center",
"Durango%20Fish%20Hatchery%20and%20Wildlife%20Museum",
"Mount%20Sanitas%20Trail",
"Cherry%20Creek%20State%20Park",
"North%20Clear%20Creek%20Falls",
"Winter%20Park%20Resort",
"Dinosaur%20Ridge",
"Colorado%20Gators%20Reptile%20Park",
"Monte%20Vista%20National%20Wildlife%20Refuge",
"Rocky%20Mountain%20Wildlife%20Park",
"Rocky%20Mountain%20Arsenal%20National%20Wildlife%20Refuge",
"Maroon%20Bells-Snowmass%20Wilderness%20Area",
"Royal%20Gorge%20Bridge%20and%20Park",
"Dennis%20Weaver%20Memorial%20Park",
"Aurora%20Reservoir",
"Mount%20Zirkel%20Wilderness%20Area",
"Summit%20Lake%20Park",
"Bear%20Creek%20Nature%20Center",
"Lookout%20Mountain%20Nature%20Center",
"Picketwire%20Canyonlands",
"Mission: Wolf",
"Many%20Parks%20Curve%20Overlook",
"Leadville%20National%20Fish%20Hatchery",
"Garden%20of%20the%20Gods",
"Benson%20Park%20Sculpture%20Garden",
"Chautauqua%20Park",
"Denver%20Mountain%20Parks",
"The%20John%20Denver%20Sanctuary",
"Box%20Canyon%20Waterfall & Park",
"North%20Cheyenne%20Canon%20Park%20and%20Starsmore%20Discovery%20Center",
"Red%20Rock%20Canyon",
"Riverside%20Park",
"Buena%20Vista%20River%20Park",
"Estes%20Park%20Visitor%20Center",
"Washington%20Park",
"Alderfer/Three%20Sisters%20Park",
"The%20Paint%20Mines%20Interpretive%20Park",
"Frisco%20Adventure%20Park",
"Fox%20Run%20Regional%20Park",
"Canyon%20View%20Park",
"Cheesman%20Park",
"City%20Park - Denver",
"Spring%20Canyon%20Community%20Park",
"Rock%20Park",
"Town%20Park",
"Carter%20Park",
"Dolores%20River%20Canyon",
"Trinidad%20Lake%20State%20Park",
"Estes%20Valley%20Dog%20Park",
"Ouray%20Ice%20Park",
"Ute%20Mountain%20Tribal%20Park",
"Daniel’s%20Gate%20Park",
"South%20Park%20City%20Museum",
"Animas%20Forks",
"Crested%20Butte%20Mountain%20Resort",
"St. Elmo",
"Ashcroft%20Ghost%20Town",
"Gothic",
"Tin%20Cup",
"Cliff%20Palace",
"Balcony%20House",
"Bent's%20Old%20Fort%20National%20Historic%20Site",
"Rosemount%20Museum",
"Rock%20Ledge%20Ranch%20Historic%20Site",
"Petroglyph%20Point%20Hike",
"New%20Sheridan%20Hotel",
"Bachelor%20Loop",
"Denver%20Union%20Station",
"Molly%20Brown%20House%20Museum",
"Tread%20of%20Pioneers%20Museum",
"Landmark's%20Mayan%20Theatre",
"Peterson%20Air & Space%20Museum",
"Last%20Chance%20Mine",
"Byers-Evans%20House",
"Old%20Homestead%20House%20Museum",
"Historic%20Olde%20Town%20Arvada",
"Western%20Slope%20Vietnam%20War%20Memorial",
"Temple%20Israel",
"Holzwarth%20Historical%20Site",
"Mayflower%20Gold%20Mill",
"Independence%20Pass",
"Loveland%20Pass",
"Park%20Point",
"Kit%20Carson%20County%20Carousel",
"Main%20Street",
"Dinosaur%20National%20Monument",
"Pikes%20Peak - America's%20Mountain",
"Steamboat%20Ski%20Resort",
"Historic%20Downtown%20Durango",
"Pearl%20Street%20Mall",
"Olympic%20Training%20Center",
"Starr%20Kempf's%20Metal%20Sculptures",
"Main%20Street",
"Canyon%20View%20Park",
"Step%20House",
"Sapphire%20Point%20Overlook",
"Landmark's%20Mayan%20Theatre",
"Ivywild%20School",
"Fraser%20Tubing%20Hill",
"Larimer%20Square",
"Toh-Atin%20Gallery",
"Bishop%20Castle",
"Wheeler%20Opera%20House",
"Center%20for%20American%20Values",
"Oxygen%20Bar",
"Historic%20Olde%20Town%20Arvada",
"Crystal%20Mill",
"Eldorado%20Canyon",
"Glenwood%20Canyon%20Bike%20Trail",
"Deer%20Creek%20Canyon%20Park",
"Glenwood%20Canyon",
"Picketwire%20Canyonlands"]
for place in places:
	place =place.replace(" ","%20")
	url = 'https://api.opencagedata.com/geocode/v1/json?q='+place+'&key=e9371220b0d64866ab25b1760944394f'
	print(url)
	http = urllib3.PoolManager()
	response = http.request('GET', url)
	soup = BeautifulSoup(response.data)
	newDictionary=json.loads(soup.text)
	print(newDictionary)
	lat = '%.3f'%(newDictionary["results"][0]['geometry']['lat'])
	lng = '%.3f'%(newDictionary["results"][0]['geometry']['lng'])


	q = str(lat)+","+str(lng)
	url = 'http://api.worldweatheronline.com/premium/v1/weather.ashx?key=db4faa45fbee429691655232192803&q='+q+'&format=json&mca=yes'
	response = http.request('GET', url)
	soup = BeautifulSoup(response.data)
	newDictionary=json.loads(soup.text)
	print(newDictionary['data']['ClimateAverages'][0]['month'])
	print("--------------------------------------------------")
# Out:
# https://api.opencagedata.com/geocode/v1/json?q=Colorado%20National%20Monument&key=e9371220b0d64866ab25b1760944394f
# /usr/lib/python3/dist-packages/bs4/__init__.py:181: UserWarning: No parser was explicitly specified, so I'm using the best available HTML parser for this system ("lxml"). This usually isn't a problem, but if you run this code on another system, or in a different virtual environment, it may use a different parser and behave differently.
#
# The code that caused this warning is on line 193 of the file /usr/lib/python3.6/runpy.py. To get rid of this warning, change code that looks like this:
#
#  BeautifulSoup(YOUR_MARKUP})
#
# to this:
#
#  BeautifulSoup(YOUR_MARKUP, "lxml")
#
#   markup_type=markup_type))
# {'documentation': 'https://opencagedata.com/api', 'licenses': [{'name': 'CC-BY-SA', 'url': 'https://creativecommons.org/licenses/by-sa/3.0/'}, {'name': 'ODbL', 'url': 'https://opendatacommons.org/licenses/odbl/summary/'}], 'rate': {'limit': 2500, 'remaining': 2203, 'reset': 1553817600}, 'results': [{'annotations': {'DMS': {'lat': "39° 3' 4.07808'' N", 'lng': "108° 41' 52.60380'' W"}, 'FIPS': {'county': '08077', 'state': '08'}, 'MGRS': '12SXJ9920624972', 'Maidenhead': 'DM59pb62fg', 'Mercator': {'x': -12100199.945, 'y': 4702074.567}, 'OSM': {'edit_url': 'https://www.openstreetmap.org/edit?relation=5453168#map=17/39.05113/-108.69795', 'url': 'https://www.openstreetmap.org/?mlat=39.05113&mlon=-108.69795#map=17/39.05113/-108.69795'}, 'callingcode': 1, 'currency': {'alternate_symbols': ['US$'], 'decimal_mark': '.', 'disambiguate_symbol': 'US$', 'html_entity': '$', 'iso_code': 'USD', 'iso_numeric': 840, 'name': 'United States Dollar', 'smallest_denomination': 1, 'subunit': 'Cent', 'subunit_to_unit': 100, 'symbol': '$', 'symbol_first': 1, 'thousands_separator': ','}, 'flag': '🇺🇸', 'geohash': '9wfwnt0966c29g0rv6w2', 'qibla': 31.8, 'sun': {'rise': {'apparent': 1553778180, 'astronomical': 1553772780, 'civil': 1553776620, 'nautical': 1553774700}, 'set': {'apparent': 1553736840, 'astronomical': 1553742300, 'civil': 1553738460, 'nautical': 1553740380}}, 'timezone': {'name': 'America/Denver', 'now_in_dst': 1, 'offset_sec': -21600, 'offset_string': -600, 'short_name': 'MDT'}, 'what3words': {'words': 'unnamed.credential.bicycle'}, 'wikidata': 'Q1111312'}, 'bounds': {'northeast': {'lat': 39.1207567, 'lng': -108.6216209}, 'southwest': {'lat': 38.9775403, 'lng': -108.7569982}}, 'components': {'ISO_3166-1_alpha-2': 'US', 'ISO_3166-1_alpha-3': 'USA', '_type': 'road', 'continent': 'North America', 'country': 'USA', 'country_code': 'us', 'county': 'Mesa County', 'path': 'Liberty Cap Trail', 'postcode': '81507', 'state': 'Colorado', 'state_code': 'CO', 'unknown': 'Colorado National Monument'}, 'confidence': 6, 'formatted': 'Colorado National Monument, Liberty Cap Trail, Mesa County, CO 81507, United States of America', 'geometry': {'lat': 39.0511328, 'lng': -108.6979455}}, {'annotations': {'DMS': {'lat': "39° 3' 34.93476'' N", 'lng': "108° 41' 59.35344'' W"}, 'FIPS': {'county': '08077', 'state': '08'}, 'MGRS': '12SXJ9902025920', 'Maidenhead': 'DM59pb64ah', 'Mercator': {'x': -12100408.656, 'y': 4703298.329}, 'OSM': {'edit_url': 'https://www.openstreetmap.org/edit?node=358942938#map=17/39.05970/-108.69982', 'url': 'https://www.openstreetmap.org/?mlat=39.05970&mlon=-108.69982#map=17/39.05970/-108.69982'}, 'callingcode': 1, 'currency': {'alternate_symbols': ['US$'], 'decimal_mark': '.', 'disambiguate_symbol': 'US$', 'html_entity': '$', 'iso_code': 'USD', 'iso_numeric': 840, 'name': 'United States Dollar', 'smallest_denomination': 1, 'subunit': 'Cent', 'subunit_to_unit': 100, 'symbol': '$', 'symbol_first': 1, 'thousands_separator': ','}, 'flag': '🇺🇸', 'geohash': '9wfwnqx5q8e69nr22y4q', 'qibla': 31.8, 'sun': {'rise': {'apparent': 1553778180, 'astronomical': 1553772780, 'civil': 1553776620, 'nautical': 1553774700}, 'set': {'apparent': 1553736840, 'astronomical': 1553742300, 'civil': 1553738460, 'nautical': 1553740380}}, 'timezone': {'name': 'America/Denver', 'now_in_dst': 1, 'offset_sec': -21600, 'offset_string': -600, 'short_name': 'MDT'}, 'what3words': {'words': 'buffer.ideal.standstill'}}, 'bounds': {'northeast': {'lat': 39.0597541, 'lng': -108.6997704}, 'southwest': {'lat': 39.0596541, 'lng': -108.6998704}}, 'components': {'ISO_3166-1_alpha-2': 'US', 'ISO_3166-1_alpha-3': 'USA', '_type': 'park', 'continent': 'North America', 'country': 'USA', 'country_code': 'us', 'county': 'Mesa County', 'park': 'Colorado National Monument', 'state': 'Colorado', 'state_code': 'CO'}, 'confidence': 9, 'formatted': 'Colorado National Monument, Mesa County, CO, United States of America', 'geometry': {'lat': 39.0597041, 'lng': -108.6998204}}], 'status': {'code': 200, 'messag ...
# [{'index': '1', 'name': 'January', 'avgMinTemp': '-8.3', 'avgMinTemp_F': '17.0', 'absMaxTemp': '5.364968', 'absMaxTemp_F': '41.7', 'avgDailyRainfall': '0.36'}, {'index': '2', 'name': 'February', 'avgMinTemp': '-5.6', 'avgMinTemp_F': '22.0', 'absMaxTemp': '7.275143', 'absMaxTemp_F': '45.1', 'avgDailyRainfall': '0.52'}, {'index': '3', 'name': 'March', 'avgMinTemp': '-0.4', 'avgMinTemp_F': '31.2', 'absMaxTemp': '12.52023', 'absMaxTemp_F': '54.5', 'avgDailyRainfall': '0.52'}, {'index': '4', 'name': 'April', 'avgMinTemp': '2.3', 'avgMinTemp_F': '36.2', 'absMaxTemp': '15.50763', 'absMaxTemp_F': '59.9', 'avgDailyRainfall': '0.61'}, {'index': '5', 'name': 'May', 'avgMinTemp': '6.6', 'avgMinTemp_F': '43.8', 'absMaxTemp': '22.0409', 'absMaxTemp_F': '71.7', 'avgDailyRainfall': '0.58'}, {'index': '6', 'name': 'June', 'avgMinTemp': '12.3', 'avgMinTemp_F': '54.1', 'absMaxTemp': '28.98038', 'absMaxTemp_F': '84.2', 'avgDailyRainfall': '0.45'}, {'index': '7', 'name': 'July', 'avgMinTemp': '15.7', 'avgMinTemp_F': '60.2', 'absMaxTemp': '30.79616', 'absMaxTemp_F': '87.4', 'avgDailyRainfall': '0.73'}, {'index': '8', 'name': 'August', 'avgMinTemp': '14.7', 'avgMinTemp_F': '58.4', 'absMaxTemp': '29.11739', 'absMaxTemp_F': '84.4', 'avgDailyRainfall': '0.82'}, {'index': '9', 'name': 'September', 'avgMinTemp': '11.4', 'avgMinTemp_F': '52.6', 'absMaxTemp': '25.54943', 'absMaxTemp_F': '78.0', 'avgDailyRainfall': '0.61'}, {'index': '10', 'name': 'October', 'avgMinTemp': '5.0', 'avgMinTemp_F': '41.0', 'absMaxTemp': '17.8781', 'absMaxTemp_F': '64.2', 'avgDailyRainfall': '0.91'}, {'index': '11', 'name': 'November', 'avgMinTemp': '-1.2', 'avgMinTemp_F': '29.8', 'absMaxTemp': '12.8935', 'absMaxTemp_F': '55.2', 'avgDailyRainfall': '0.40'}, {'index': '12', 'name': 'December', 'avgMinTemp': '-6.9', 'avgMinTemp_F': '19.6', 'absMaxTemp': '6.355548', 'absMaxTemp_F': '43.4', 'avgDailyRainfall': '0.50'}]
# --------------------------------------------------
# https://api.opencagedata.com/geocode/v1/json?q=History%20Colorado%20Center&key=e9371220b0d64866ab25b1760944394f
# {'documentation': 'https://opencagedata.com/api', 'licenses': [{'name': 'CC-BY-SA', 'url': 'https://creativecommons.org/licenses/by-sa/3.0/'}, {'name': 'ODbL', 'url': 'https://opendatacommons.org/licenses/odbl/summary/'}], 'rate': {'limit': 2500, 'remaining': 2202, 'reset': 1553817600}, 'results': [{'annotations': {'DMS': {'lat': "39° 44' 8.40552'' N", 'lng': "104° 59' 12.16284'' W"}, 'FIPS': {'county': '08031', 'state': '08'}, 'MGRS': '13SED0113898419', 'Maidenhead': 'DM79mr16on', 'Mercator': {'x': -11687067.311, 'y': 4800285.043}, 'OSM': {'edit_url': 'https://www.openstreetmap.org/edit?way=105429742#map=17/39.73567/-104.98671', 'url': 'https://www.openstreetmap.org/?mlat=39.73567&mlon=-104.98671#map=17/39.73567/-104.98671'}, 'callingcode': 1, 'currency': {'alternate_symbols': ['US$'], 'decimal_mark': '.', 'disambiguate_symbol': 'US$', 'html_entity': '$', 'iso_code': 'USD', 'iso_numeric': 840, 'name': 'United States Dollar', 'smallest_denomination': 1, 'subunit': 'Cent', 'subunit_to_unit': 100, 'symbol': '$', 'symbol_first': 1, 'thousands_separator': ','}, 'flag': '🇺🇸', 'geohash': '9xj64cxj033tkd4m8kht', 'qibla': 34.96, 'sun': {'rise': {'apparent': 1553777280, 'astronomical': 1553771820, 'civil': 1553775660, 'nautical': 1553773740}, 'set': {'apparent': 1553736000, 'astronomical': 1553741520, 'civil': 1553737620, 'nautical': 1553739540}}, 'timezone': {'name': 'America/Denver', 'now_in_dst': 1, 'offset_sec': -21600, 'offset_string': -600, 'short_name': 'MDT'}, 'what3words': {'words': 'feast.ears.await'}}, 'bounds': {'northeast': {'lat': 39.7359713, 'lng': -104.9862854}, 'southwest': {'lat': 39.7353968, 'lng': -104.9871922}}, 'components': {'ISO_3166-1_alpha-2': 'US', 'ISO_3166-1_alpha-3': 'USA', '_type': 'museum', 'city': 'Denver', 'continent': 'North America', 'country': 'USA', 'country_code': 'us', 'county': 'Denver County', 'house_number': '1200', 'museum': 'History Colorado Center', 'neighbourhood': 'Civic Center', 'postcode': '80203', 'road': 'Broadway', 'state': 'Colorado', 'state_code': 'CO'}, 'confidence': 9, 'formatted': 'History Colorado Center, 1200 Broadway, Denver, CO 80203, United States of America', 'geometry': {'lat': 39.7356682, 'lng': -104.9867119}}], 'status': {'code': 200, 'message': 'OK'}, 'stay_informed': {'blog': 'https://blog.opencagedata.com', 'twitter': 'https://twitter.com/opencagedata'}, 'thanks': 'For using an OpenCage Data API', 'timestamp': {'created_http': 'Thu, 28 Mar 2019 09:36:52 GMT', 'created_unix': 1553765812}, 'total_results': 1}
# [{'index': '1', 'name': 'January', 'avgMinTemp': '-6.2', 'avgMinTemp_F': '20.8', 'absMaxTemp': '7.436032', 'absMaxTemp_F': '45.4', 'avgDailyRainfall': '0.33'}, {'index': '2', 'name': 'February', 'avgMinTemp': '-6.3', 'avgMinTemp_F': '20.6', 'absMaxTemp': '9.168357', 'absMaxTemp_F': '48.5', 'avgDailyRainfall': '0.51'}, {'index': '3', 'name': 'March', 'avgMinTemp': '-1.8', 'avgMinTemp_F': '28.7', 'absMaxTemp': '14.60597', 'absMaxTemp_F': '58.3', 'avgDailyRainfall': '0.64'}, {'index': '4', 'name': 'April', 'avgMinTemp': '0.2', 'avgMinTemp_F': '32.4', 'absMaxTemp': '17.34157', 'absMaxTemp_F': '63.2', 'avgDailyRainfall': '0.95'}, {'index': '5', 'name': 'May', 'avgMinTemp': '5.0', 'avgMinTemp_F': '40.9', 'absMaxTemp': '21.30432', 'absMaxTemp_F': '70.3', 'avgDailyRainfall': '1.43'}, {'index': '6', 'name': 'June', 'avgMinTemp': '11.5', 'avgMinTemp_F': '52.7', 'absMaxTemp': '29.51063', 'absMaxTemp_F': '85.1', 'avgDailyRainfall': '0.76'}, {'index': '7', 'name': 'July', 'avgMinTemp': '14.1', 'avgMinTemp_F': '57.3', 'absMaxTemp': '30.27995', 'absMaxTemp_F': '86.5', 'avgDailyRainfall': '0.98'}, {'index': '8', 'name': 'August', 'avgMinTemp': '13.1', 'avgMinTemp_F': '55.7', 'absMaxTemp': '29.59971', 'absMaxTemp_F': '85.3', 'avgDailyRainfall': '0.65'}, {'index': '9', 'name': 'September', 'avgMinTemp': '10.1', 'avgMinTemp_F': '50.3', 'absMaxTemp': '27.10123', 'absMaxTemp_F': '80.8', 'avgDailyRainfall': '0.50'}, {'index': '10', 'name': 'October', 'avgMinTemp': '3.5', 'avgMinTemp_F': '38.3', 'absMaxTemp': '21.12929', 'absMaxTemp_F': '70.0', 'avgDailyRainfall': '0.54'}, {'index': '11', 'name': 'November', 'avgMinTemp': '-1.8', 'avgMinTemp_F': '28.8', 'absMaxTemp': '14.08667', 'absMaxTemp_F': '57.4', 'avgDailyRainfall': '0.33'}, {'index': '12', 'name': 'December', 'avgMinTemp': '-6.9', 'avgMinTemp_F': '19.6', 'absMaxTemp': '7.409968', 'absMaxTemp_F': '45.3', 'avgDailyRainfall': '0.25'}]
# --------------------------------------------------
# https://api.opencagedata.com/geocode/v1/json?q=Colorado%20Provencal&key=e9371220b0d64866ab25b1760944394f
# {'documentation': 'https://opencagedata.com/api', 'licenses': [{'name': 'CC-BY-SA', 'url': 'https://creativecommons.org/licenses/by-sa/3.0/'}, {'name': 'ODbL', 'url': 'https://opendatacommons.org/licenses/odbl/summary/'}], 'rate': {'limit': 2500, 'remaining': 2201, 'reset': 1553817600}, 'results': [{'annotations': {'DMS': {'lat': "43° 54' 51.20064'' N", 'lng': "5° 29' 46.98924'' E"}, 'MGRS': '31TGJ0043665375', 'Maidenhead': 'JN23rv99nj', 'Mercator': {'x': 611854.88, 'y': 5422531.352}, 'OSM': {'edit_url': 'https://www.openstreetmap.org/edit?node=413927021#map=17/43.91422/5.49639', 'url': 'https://www.openstreetmap.org/?mlat=43.91422&mlon=5.49639#map=17/43.91422/5.49639'}, 'callingcode': 33, 'currency': {'alternate_symbols': [], 'decimal_mark': ',', 'html_entity': '€', 'iso_code': 'EUR', 'iso_numeric': 978, 'name': 'Euro', 'smallest_denomination': 1, 'subunit': 'Cent', 'subunit_to_unit': 100, 'symbol': '€', 'symbol_first': 1, 'thousands_separator': '.'}, 'flag': '🇫🇷', 'geohash': 'spgcv466gh6kk491qn6y', 'qibla': 117.22, 'sun': {'rise': {'apparent': 1553750820, 'astronomical': 1553744880, 'civil': 1553749080, 'nautical': 1553747040}, 'set': {'apparent': 1553796000, 'astronomical': 1553801940, 'civil': 1553797740, 'nautical': 1553799840}}, 'timezone': {'name': 'Europe/Paris', 'now_in_dst': 0, 'offset_sec': 3600, 'offset_string': 100, 'short_name': 'CET'}, 'what3words': {'words': 'swirled.queried.medicines'}, 'wikidata': 'Q2984389'}, 'bounds': {'northeast': {'lat': 43.9142724, 'lng': 5.4964359}, 'southwest': {'lat': 43.9141724, 'lng': 5.4963359}}, 'components': {'ISO_3166-1_alpha-2': 'FR', 'ISO_3166-1_alpha-3': 'FRA', '_type': 'road', 'continent': 'Europe', 'country': 'France', 'country_code': 'fr', 'county': 'Apt', 'political_union': 'European Union', 'postcode': '84400', 'road': 'Chemin de Saint-Joseph', 'state': "Provence-Alpes-Côte d'Azur", 'state_code': 'PAC', 'state_district': 'Vaucluse', 'suburb': "L'Avocate", 'unknown': 'Le Colorado Provençal', 'village': 'Rustrel'}, 'confidence': 9, 'formatted': 'Le Colorado Provençal, Chemin de Saint-Joseph, 84400 Rustrel, France', 'geometry': {'lat': 43.9142224, 'lng': 5.4963859}}, {'annotations': {'DMS': {'lat': "43° 55' 10.92468'' N", 'lng': "5° 30' 1.39356'' E"}, 'MGRS': '31TGJ0073865993', 'Maidenhead': 'JN23sw00br', 'Mercator': {'x': 612300.295, 'y': 5423375.082}, 'OSM': {'edit_url': 'https://www.openstreetmap.org/edit?way=304864370#map=17/43.91970/5.50039', 'url': 'https://www.openstreetmap.org/?mlat=43.91970&mlon=5.50039#map=17/43.91970/5.50039'}, 'callingcode': 33, 'currency': {'alternate_symbols': [], 'decimal_mark': ',', 'html_entity': '€', 'iso_code': 'EUR', 'iso_numeric': 978, 'name': 'Euro', 'smallest_denomination': 1, 'subunit': 'Cent', 'subunit_to_unit': 100, 'symbol': '€', 'symbol_first': 1, 'thousands_separator': '.'}, 'flag': '🇫🇷', 'geohash': 'spgcv5m6b39yvn5vqnc2', 'qibla': 117.23, 'sun': {'rise': {'apparent': 1553750820, 'astronomical': 1553744880, 'civil': 1553749080, 'nautical': 1553747040}, 'set': {'apparent': 1553796000, 'astronomical': 1553801940, 'civil': 1553797740, 'nautical': 1553799840}}, 'timezone': {'name': 'Europe/Paris', 'now_in_dst': 0, 'offset_sec': 3600, 'offset_string': 100, 'short_name': 'CET'}, 'what3words': {'words': 'haystack.foils.satchels'}}, 'bounds': {'northeast': {'lat': 43.9200596, 'lng': 5.5014748}, 'southwest': {'lat': 43.9193844, 'lng': 5.4987468}}, 'components': {'ISO_3166-1_alpha-2': 'FR', 'ISO_3166-1_alpha-3': 'FRA', '_type': 'parking', 'continent': 'Europe', 'country': 'France', 'country_code': 'fr', 'county': 'Apt', 'parking': 'Les Mille Couleurs', 'political_union': 'European Union', 'postcode': '84400', 'road': 'D 22', 'state': "Provence-Alpes-Côte d'Azur", 'state_code': 'PAC', 'state_district': 'Vaucluse', 'village': 'Gignac'}, 'confidence': 9, 'formatted': 'Les Mille Couleurs, D 22, 84400 Gignac, France', 'geometry': {'lat': 43.9197013, 'lng': 5.5003871}}, {'annotations': {'DMS': {'lat': "31° 39' 10.62000'' N", 'lng': "93° 12' 7.5 ...
# [{'index': '1', 'name': 'January', 'avgMinTemp': '-0.6', 'avgMinTemp_F': '31.0', 'absMaxTemp': '8.015613', 'absMaxTemp_F': '46.4', 'avgDailyRainfall': '1.57'}, {'index': '2', 'name': 'February', 'avgMinTemp': '-1.0', 'avgMinTemp_F': '30.2', 'absMaxTemp': '10.34643', 'absMaxTemp_F': '50.6', 'avgDailyRainfall': '2.07'}, {'index': '3', 'name': 'March', 'avgMinTemp': '2.4', 'avgMinTemp_F': '36.3', 'absMaxTemp': '14.30368', 'absMaxTemp_F': '57.7', 'avgDailyRainfall': '1.79'}, {'index': '4', 'name': 'April', 'avgMinTemp': '5.6', 'avgMinTemp_F': '42.1', 'absMaxTemp': '17.39717', 'absMaxTemp_F': '63.3', 'avgDailyRainfall': '1.89'}, {'index': '5', 'name': 'May', 'avgMinTemp': '8.1', 'avgMinTemp_F': '46.5', 'absMaxTemp': '22.25842', 'absMaxTemp_F': '72.1', 'avgDailyRainfall': '2.44'}, {'index': '6', 'name': 'June', 'avgMinTemp': '11.8', 'avgMinTemp_F': '53.2', 'absMaxTemp': '24.34443', 'absMaxTemp_F': '75.8', 'avgDailyRainfall': '2.89'}, {'index': '7', 'name': 'July', 'avgMinTemp': '13.9', 'avgMinTemp_F': '57.1', 'absMaxTemp': '28.13939', 'absMaxTemp_F': '82.7', 'avgDailyRainfall': '1.90'}, {'index': '8', 'name': 'August', 'avgMinTemp': '13.8', 'avgMinTemp_F': '56.9', 'absMaxTemp': '29.45703', 'absMaxTemp_F': '85.0', 'avgDailyRainfall': '1.84'}, {'index': '9', 'name': 'September', 'avgMinTemp': '10.8', 'avgMinTemp_F': '51.4', 'absMaxTemp': '23.32217', 'absMaxTemp_F': '74.0', 'avgDailyRainfall': '2.19'}, {'index': '10', 'name': 'October', 'avgMinTemp': '7.4', 'avgMinTemp_F': '45.4', 'absMaxTemp': '18.41948', 'absMaxTemp_F': '65.2', 'avgDailyRainfall': '2.72'}, {'index': '11', 'name': 'November', 'avgMinTemp': '3.6', 'avgMinTemp_F': '38.4', 'absMaxTemp': '12.58157', 'absMaxTemp_F': '54.6', 'avgDailyRainfall': '3.28'}, {'index': '12', 'name': 'December', 'avgMinTemp': '0.3', 'avgMinTemp_F': '32.5', 'absMaxTemp': '8.850178', 'absMaxTemp_F': '47.9', 'avgDailyRainfall': '1.84'}]
# --------------------------------------------------
# https://api.opencagedata.com/geocode/v1/json?q=Colrado%20Convention%20Center&key=e9371220b0d64866ab25b1760944394f
# {'documentation': 'https://opencagedata.com/api', 'licenses': [{'name': 'CC-BY-SA', 'url': 'https://creativecommons.org/licenses/by-sa/3.0/'}, {'name': 'ODbL', 'url': 'https://opendatacommons.org/licenses/odbl/summary/'}], 'rate': {'limit': 2500, 'remaining': 2200, 'reset': 1553817600}, 'results': [{'annotations': {'DMS': {'lat': "7° 15' 0.00000'' N", 'lng': "2° 10' 0.01200'' E"}, 'MGRS': '31NDJ0800401470', 'Maidenhead': 'JJ17cg00aa', 'Mercator': {'x': 241192.601, 'y': 803840.093}, 'OSM': {'url': 'https://www.openstreetmap.org/?mlat=7.25000&mlon=2.16667#map=17/7.25000/2.16667'}, 'callingcode': 229, 'flag': '🇧🇯', 'geohash': 's1391rcdr1fnxfqrwhd7', 'qibla': 64.66, 'sun': {'rise': {'apparent': 1553752260, 'astronomical': 1553748120, 'civil': 1553751060, 'nautical': 1553749560}, 'set': {'apparent': 1553796060, 'astronomical': 1553800260, 'civil': 1553797320, 'nautical': 1553798760}}, 'timezone': {'name': 'Africa/Lagos', 'now_in_dst': 0, 'offset_sec': 3600, 'offset_string': 100, 'short_name': 'WAT'}, 'what3words': {'words': 'shirk.rivet.blemishes'}}, 'bounds': {'northeast': {'lat': 7.6324027, 'lng': 2.5600818}, 'southwest': {'lat': 6.9119298, 'lng': 1.6228549}}, 'components': {'ISO_3166-1_alpha-2': 'BJ', 'ISO_3166-1_alpha-3': 'BEN', '_type': 'state', 'continent': 'Africa', 'country': 'Benin', 'country_code': 'bj', 'state': 'Zou Department'}, 'confidence': 1, 'formatted': 'Zou Department, Benin', 'geometry': {'lat': 7.25, 'lng': 2.16667}}], 'status': {'code': 200, 'message': 'OK'}, 'stay_informed': {'blog': 'https://blog.opencagedata.com', 'twitter': 'https://twitter.com/opencagedata'}, 'thanks': 'For using an OpenCage Data API', 'timestamp': {'created_http': 'Thu, 28 Mar 2019 09:36:58 GMT', 'created_unix': 1553765818}, 'total_results': 1}
# [{'index': '1', 'name': 'January', 'avgMinTemp': '22.6', 'avgMinTemp_F': '72.6', 'absMaxTemp': '38.92258', 'absMaxTemp_F': '102.1', 'avgDailyRainfall': '0.19'}, {'index': '2', 'name': 'February', 'avgMinTemp': '24.6', 'avgMinTemp_F': '76.3', 'absMaxTemp': '39.48896', 'absMaxTemp_F': '103.1', 'avgDailyRainfall': '0.68'}, {'index': '3', 'name': 'March', 'avgMinTemp': '25.1', 'avgMinTemp_F': '77.3', 'absMaxTemp': '38.58368', 'absMaxTemp_F': '101.5', 'avgDailyRainfall': '0.98'}, {'index': '4', 'name': 'April', 'avgMinTemp': '25.1', 'avgMinTemp_F': '77.2', 'absMaxTemp': '37.4304', 'absMaxTemp_F': '99.4', 'avgDailyRainfall': '1.06'}, {'index': '5', 'name': 'May', 'avgMinTemp': '24.6', 'avgMinTemp_F': '76.3', 'absMaxTemp': '36.20426', 'absMaxTemp_F': '97.2', 'avgDailyRainfall': '1.67'}, {'index': '6', 'name': 'June', 'avgMinTemp': '23.3', 'avgMinTemp_F': '74.0', 'absMaxTemp': '33.37307', 'absMaxTemp_F': '92.1', 'avgDailyRainfall': '1.69'}, {'index': '7', 'name': 'July', 'avgMinTemp': '22.5', 'avgMinTemp_F': '72.4', 'absMaxTemp': '31.56439', 'absMaxTemp_F': '88.8', 'avgDailyRainfall': '2.21'}, {'index': '8', 'name': 'August', 'avgMinTemp': '22.1', 'avgMinTemp_F': '71.7', 'absMaxTemp': '31.03829', 'absMaxTemp_F': '87.9', 'avgDailyRainfall': '2.81'}, {'index': '9', 'name': 'September', 'avgMinTemp': '22.6', 'avgMinTemp_F': '72.7', 'absMaxTemp': '31.84327', 'absMaxTemp_F': '89.3', 'avgDailyRainfall': '3.20'}, {'index': '10', 'name': 'October', 'avgMinTemp': '23.2', 'avgMinTemp_F': '73.7', 'absMaxTemp': '33.59613', 'absMaxTemp_F': '92.5', 'avgDailyRainfall': '2.13'}, {'index': '11', 'name': 'November', 'avgMinTemp': '23.5', 'avgMinTemp_F': '74.3', 'absMaxTemp': '36.38', 'absMaxTemp_F': '97.5', 'avgDailyRainfall': '0.41'}, {'index': '12', 'name': 'December', 'avgMinTemp': '22.8', 'avgMinTemp_F': '73.0', 'absMaxTemp': '37.89355', 'absMaxTemp_F': '100.2', 'avgDailyRainfall': '0.09'}]
# --------------------------------------------------
# https://api.opencagedata.com/geocode/v1/json?q=Colorado%20State%20Capital&key=e9371220b0d64866ab25b1760944394f
# {'documentation': 'https://opencagedata.com/api', 'licenses': [{'name': 'CC-BY-SA', 'url': 'https://creativecommons.org/licenses/by-sa/3.0/'}, {'name': 'ODbL', 'url': 'https://opendatacommons.org/licenses/odbl/summary/'}], 'rate': {'limit': 2500, 'remaining': 2199, 'reset': 1553817600}, 'results': [{'annotations': {'DMS': {'lat': "10° 15' 29.46456'' N", 'lng': "66° 6' 12.93444'' W"}, 'MGRS': '19PHM1730635387', 'Maidenhead': 'FK60wg71nx', 'Mercator': {'x': -7358618.301, 'y': 1140481.713}, 'OSM': {'edit_url': 'https://www.openstreetmap.org/edit?node=5424623998#map=17/10.25818/-66.10359', 'url': 'https://www.openstreetmap.org/?mlat=10.25818&mlon=-66.10359#map=17/10.25818/-66.10359'}, 'callingcode': 58, 'flag': '🇻🇪', 'geohash': 'd9bfrg2y68hwembjxup3', 'qibla': 65.66, 'sun': {'rise': {'apparent': 1553768580, 'astronomical': 1553764380, 'civil': 1553767320, 'nautical': 1553765820}, 'set': {'apparent': 1553812440, 'astronomical': 1553816640, 'civil': 1553813700, 'nautical': 1553815200}}, 'timezone': {'name': 'America/Caracas', 'now_in_dst': 0, 'offset_sec': -14400, 'offset_string': -400, 'short_name': -4}, 'what3words': {'words': 'debased.blog.chortles'}}, 'bounds': {'northeast': {'lat': 10.2981846, 'lng': -66.0635929}, 'southwest': {'lat': 10.2181846, 'lng': -66.1435929}}, 'components': {'ISO_3166-1_alpha-2': 'VE', 'ISO_3166-1_alpha-3': 'VEN', '_type': 'city', 'continent': 'South America', 'country': 'Venezuela', 'country_code': 've', 'county': 'Municipio Buróz', 'state': 'Miranda', 'state_code': 'M', 'town': 'El Colorado'}, 'confidence': 7, 'formatted': 'El Colorado, Municipio Buróz, Venezuela', 'geometry': {'lat': 10.2581846, 'lng': -66.1035929}}, {'annotations': {'DMS': {'lat': "10° 10' 40.06380'' N", 'lng': "65° 57' 46.71432'' W"}, 'MGRS': '20PJS7531226554', 'Maidenhead': 'FK70ae42kq', 'Mercator': {'x': -7342964.922, 'y': 1131447.591}, 'OSM': {'edit_url': 'https://www.openstreetmap.org/edit?node=5651356583#map=17/10.17780/-65.96298', 'url': 'https://www.openstreetmap.org/?mlat=10.17780&mlon=-65.96298#map=17/10.17780/-65.96298'}, 'callingcode': 58, 'flag': '🇻🇪', 'geohash': 'd9c1fuz1zq8502v1mvwc', 'qibla': 65.71, 'sun': {'rise': {'apparent': 1553768520, 'astronomical': 1553764320, 'civil': 1553767260, 'nautical': 1553765820}, 'set': {'apparent': 1553812440, 'astronomical': 1553816640, 'civil': 1553813700, 'nautical': 1553815140}}, 'timezone': {'name': 'America/Caracas', 'now_in_dst': 0, 'offset_sec': -14400, 'offset_string': -400, 'short_name': -4}, 'what3words': {'words': 'duke.refuge.isotopes'}}, 'bounds': {'northeast': {'lat': 10.1977955, 'lng': -65.9429762}, 'southwest': {'lat': 10.1577955, 'lng': -65.9829762}}, 'components': {'ISO_3166-1_alpha-2': 'VE', 'ISO_3166-1_alpha-3': 'VEN', '_type': 'village', 'continent': 'South America', 'country': 'Venezuela', 'country_code': 've', 'county': 'Municipio Páez', 'state': 'Miranda', 'state_code': 'M', 'village': 'El Colorado'}, 'confidence': 7, 'formatted': 'El Colorado, Municipio Páez, Venezuela', 'geometry': {'lat': 10.1777955, 'lng': -65.9629762}}, {'annotations': {'DMS': {'lat': "10° 23' 0.22380'' N", 'lng': "66° 20' 20.90400'' W"}, 'MGRS': '19PGM9136849022', 'Maidenhead': 'FK60tj92ha', 'Mercator': {'x': -7384839.284, 'y': 1154557.542}, 'OSM': {'edit_url': 'https://www.openstreetmap.org/edit?node=5677448730#map=17/10.38340/-66.33914', 'url': 'https://www.openstreetmap.org/?mlat=10.38340&mlon=-66.33914#map=17/10.38340/-66.33914'}, 'callingcode': 58, 'flag': '🇻🇪', 'geohash': 'd9bg46jr9vpyy98bmb2g', 'qibla': 65.58, 'sun': {'rise': {'apparent': 1553768640, 'astronomical': 1553764440, 'civil': 1553767380, 'nautical': 1553765880}, 'set': {'apparent': 1553812500, 'astronomical': 1553816700, 'civil': 1553813760, 'nautical': 1553815260}}, 'timezone': {'name': 'America/Caracas', 'now_in_dst': 0, 'offset_sec': -14400, 'offset_string': -400, 'short_name': -4}, 'what3words': {'words': 'addressed.snake.conjugate'}}, 'bounds': {'northeast': {'lat': 10.3933955, 'lng': -66.32914}, 'southwest': {'la ...
# [{'index': '1', 'name': 'January', 'avgMinTemp': '18.9', 'avgMinTemp_F': '66.0', 'absMaxTemp': '27.58748', 'absMaxTemp_F': '81.7', 'avgDailyRainfall': '1.53'}, {'index': '2', 'name': 'February', 'avgMinTemp': '18.6', 'avgMinTemp_F': '65.4', 'absMaxTemp': '30.28821', 'absMaxTemp_F': '86.5', 'avgDailyRainfall': '1.34'}, {'index': '3', 'name': 'March', 'avgMinTemp': '19.6', 'avgMinTemp_F': '67.3', 'absMaxTemp': '31.24768', 'absMaxTemp_F': '88.2', 'avgDailyRainfall': '1.22'}, {'index': '4', 'name': 'April', 'avgMinTemp': '20.2', 'avgMinTemp_F': '68.4', 'absMaxTemp': '29.89403', 'absMaxTemp_F': '85.8', 'avgDailyRainfall': '2.97'}, {'index': '5', 'name': 'May', 'avgMinTemp': '20.6', 'avgMinTemp_F': '69.0', 'absMaxTemp': '29.65242', 'absMaxTemp_F': '85.4', 'avgDailyRainfall': '4.32'}, {'index': '6', 'name': 'June', 'avgMinTemp': '20.4', 'avgMinTemp_F': '68.8', 'absMaxTemp': '29.3229', 'absMaxTemp_F': '84.8', 'avgDailyRainfall': '3.94'}, {'index': '7', 'name': 'July', 'avgMinTemp': '20.1', 'avgMinTemp_F': '68.3', 'absMaxTemp': '28.96629', 'absMaxTemp_F': '84.1', 'avgDailyRainfall': '5.23'}, {'index': '8', 'name': 'August', 'avgMinTemp': '19.8', 'avgMinTemp_F': '67.7', 'absMaxTemp': '29.92687', 'absMaxTemp_F': '85.9', 'avgDailyRainfall': '6.56'}, {'index': '9', 'name': 'September', 'avgMinTemp': '20.0', 'avgMinTemp_F': '68.0', 'absMaxTemp': '30.08513', 'absMaxTemp_F': '86.2', 'avgDailyRainfall': '6.97'}, {'index': '10', 'name': 'October', 'avgMinTemp': '20.1', 'avgMinTemp_F': '68.3', 'absMaxTemp': '29.66826', 'absMaxTemp_F': '85.4', 'avgDailyRainfall': '10.28'}, {'index': '11', 'name': 'November', 'avgMinTemp': '20.0', 'avgMinTemp_F': '68.1', 'absMaxTemp': '28.40723', 'absMaxTemp_F': '83.1', 'avgDailyRainfall': '6.27'}, {'index': '12', 'name': 'December', 'avgMinTemp': '19.4', 'avgMinTemp_F': '66.9', 'absMaxTemp': '27.50081', 'absMaxTemp_F': '81.5', 'avgDailyRainfall': '2.22'}]
# --------------------------------------------------
# https://api.opencagedata.com/geocode/v1/json?q=Cripple%20Creek%20&%20Victor%20Narrow%20Guage%20Railroad&key=e9371220b0d64866ab25b1760944394f
# {'documentation': 'https://opencagedata.com/api', 'licenses': [{'name': 'CC-BY-SA', 'url': 'https://creativecommons.org/licenses/by-sa/3.0/'}, {'name': 'ODbL', 'url': 'https://opendatacommons.org/licenses/odbl/summary/'}], 'rate': {'limit': 2500, 'remaining': 2198, 'reset': 1553817600}, 'results': [{'annotations': {'DMS': {'lat': "38° 44' 47.95980'' N", 'lng': "105° 10' 41.93364'' W"}, 'FIPS': {'county': '08119', 'state': '08'}, 'MGRS': '13SDC8450488678', 'Maidenhead': 'DM78jr89oe', 'Mercator': {'x': -11708396.457, 'y': 4658699.916}, 'OSM': {'edit_url': 'https://www.openstreetmap.org/edit?relation=112377#map=17/38.74666/-105.17831', 'url': 'https://www.openstreetmap.org/?mlat=38.74666&mlon=-105.17831#map=17/38.74666/-105.17831'}, 'callingcode': 1, 'currency': {'alternate_symbols': ['US$'], 'decimal_mark': '.', 'disambiguate_symbol': 'US$', 'html_entity': '$', 'iso_code': 'USD', 'iso_numeric': 840, 'name': 'United States Dollar', 'smallest_denomination': 1, 'subunit': 'Cent', 'subunit_to_unit': 100, 'symbol': '$', 'symbol_first': 1, 'thousands_separator': ','}, 'flag': '🇺🇸', 'geohash': '9wvhqte7xsh553ve8czq', 'qibla': 35.01, 'sun': {'rise': {'apparent': 1553777400, 'astronomical': 1553771940, 'civil': 1553775780, 'nautical': 1553773860}, 'set': {'apparent': 1553736000, 'astronomical': 1553741400, 'civil': 1553737620, 'nautical': 1553739480}}, 'timezone': {'name': 'America/Denver', 'now_in_dst': 1, 'offset_sec': -21600, 'offset_string': -600, 'short_name': 'MDT'}, 'what3words': {'words': 'abandons.libraries.wriggling'}, 'wikidata': 'Q117605'}, 'bounds': {'northeast': {'lat': 38.759809, 'lng': -105.1677616}, 'southwest': {'lat': 38.730495, 'lng': -105.208308}}, 'components': {'ISO_3166-1_alpha-2': 'US', 'ISO_3166-1_alpha-3': 'USA', '_type': 'city', 'city': 'Cripple Creek', 'continent': 'North America', 'country': 'USA', 'country_code': 'us', 'county': 'Teller County', 'postcode': '80081', 'state': 'Colorado', 'state_code': 'CO'}, 'confidence': 7, 'formatted': 'Cripple Creek, CO 80081, United States of America', 'geometry': {'lat': 38.7466555, 'lng': -105.1783149}}, {'annotations': {'DMS': {'lat': "36° 50' 53.27880'' N", 'lng': "80° 59' 36.99960'' W"}, 'FIPS': {'county': '51197', 'state': '51'}, 'MGRS': '17SNA0056978025', 'Maidenhead': 'EM96mu03sn', 'Mercator': {'x': -9016167.534, 'y': 4392333.369}, 'OSM': {'edit_url': 'https://www.openstreetmap.org/edit?way=43235614#map=17/36.84813/-80.99361', 'url': 'https://www.openstreetmap.org/?mlat=36.84813&mlon=-80.99361#map=17/36.84813/-80.99361'}, 'callingcode': 1, 'currency': {'alternate_symbols': ['US$'], 'decimal_mark': '.', 'disambiguate_symbol': 'US$', 'html_entity': '$', 'iso_code': 'USD', 'iso_numeric': 840, 'name': 'United States Dollar', 'smallest_denomination': 1, 'subunit': 'Cent', 'subunit_to_unit': 100, 'symbol': '$', 'symbol_first': 1, 'thousands_separator': ','}, 'flag': '🇺🇸', 'geohash': 'dnw3sgyrbjf7hqbfsc0j', 'qibla': 54.12, 'sun': {'rise': {'apparent': 1553771640, 'astronomical': 1553766360, 'civil': 1553770080, 'nautical': 1553768280}, 'set': {'apparent': 1553816520, 'astronomical': 1553735400, 'civil': 1553731680, 'nautical': 1553733540}}, 'timezone': {'name': 'America/New_York', 'now_in_dst': 1, 'offset_sec': -14400, 'offset_string': -400, 'short_name': 'EDT'}, 'what3words': {'words': 'iced.jolt.excel'}}, 'bounds': {'northeast': {'lat': 36.848687, 'lng': -80.992261}, 'southwest': {'lat': 36.848085, 'lng': -80.994482}}, 'components': {'ISO_3166-1_alpha-2': 'US', 'ISO_3166-1_alpha-3': 'USA', '_type': 'stream', 'continent': 'North America', 'country': 'USA', 'country_code': 'us', 'county': 'Wythe County', 'postcode': '24350', 'state': 'Virginia', 'state_code': 'VA', 'stream': 'Cripple Creek'}, 'confidence': 9, 'formatted': 'Cripple Creek, Wythe County, VA 24350, United States of America', 'geometry': {'lat': 36.848133, 'lng': -80.993611}}, {'annotations': {'DMS': {'lat': "36° 48' 59.88240'' N", 'lng': "81° 14' 34.06560'' W"}, 'FIPS': {'county': '51197', 'state': '51'}, ' ...
# [{'index': '1', 'name': 'January', 'avgMinTemp': '-7.1', 'avgMinTemp_F': '19.2', 'absMaxTemp': '6.048161', 'absMaxTemp_F': '42.9', 'avgDailyRainfall': '0.60'}, {'index': '2', 'name': 'February', 'avgMinTemp': '-7.1', 'avgMinTemp_F': '19.3', 'absMaxTemp': '7.507786', 'absMaxTemp_F': '45.5', 'avgDailyRainfall': '0.64'}, {'index': '3', 'name': 'March', 'avgMinTemp': '-2.8', 'avgMinTemp_F': '27.0', 'absMaxTemp': '11.81242', 'absMaxTemp_F': '53.3', 'avgDailyRainfall': '0.70'}, {'index': '4', 'name': 'April', 'avgMinTemp': '-0.5', 'avgMinTemp_F': '31.1', 'absMaxTemp': '14.89603', 'absMaxTemp_F': '58.8', 'avgDailyRainfall': '1.11'}, {'index': '5', 'name': 'May', 'avgMinTemp': '4.1', 'avgMinTemp_F': '39.5', 'absMaxTemp': '20.03068', 'absMaxTemp_F': '68.1', 'avgDailyRainfall': '1.65'}, {'index': '6', 'name': 'June', 'avgMinTemp': '10.4', 'avgMinTemp_F': '50.8', 'absMaxTemp': '26.35063', 'absMaxTemp_F': '79.4', 'avgDailyRainfall': '1.30'}, {'index': '7', 'name': 'July', 'avgMinTemp': '12.8', 'avgMinTemp_F': '55.0', 'absMaxTemp': '27.20487', 'absMaxTemp_F': '81.0', 'avgDailyRainfall': '2.42'}, {'index': '8', 'name': 'August', 'avgMinTemp': '11.7', 'avgMinTemp_F': '53.0', 'absMaxTemp': '26.75929', 'absMaxTemp_F': '80.2', 'avgDailyRainfall': '1.89'}, {'index': '9', 'name': 'September', 'avgMinTemp': '8.9', 'avgMinTemp_F': '48.1', 'absMaxTemp': '24.49427', 'absMaxTemp_F': '76.1', 'avgDailyRainfall': '1.04'}, {'index': '10', 'name': 'October', 'avgMinTemp': '2.5', 'avgMinTemp_F': '36.4', 'absMaxTemp': '17.57574', 'absMaxTemp_F': '63.6', 'avgDailyRainfall': '0.86'}, {'index': '11', 'name': 'November', 'avgMinTemp': '-2.9', 'avgMinTemp_F': '26.8', 'absMaxTemp': '12.1262', 'absMaxTemp_F': '53.8', 'avgDailyRainfall': '0.40'}, {'index': '12', 'name': 'December', 'avgMinTemp': '-7.7', 'avgMinTemp_F': '18.1', 'absMaxTemp': '6.252162', 'absMaxTemp_F': '43.3', 'avgDailyRainfall': '0.45'}]
# --------------------------------------------------
# https://api.opencagedata.com/geocode/v1/json?q=Cumbres%20Creek%20&%20Toltec%20Scenic%20Railroad&key=e9371220b0d64866ab25b1760944394f
# {'documentation': 'https://opencagedata.com/api', 'licenses': [{'name': 'CC-BY-SA', 'url': 'https://creativecommons.org/licenses/by-sa/3.0/'}, {'name': 'ODbL', 'url': 'https://opendatacommons.org/licenses/odbl/summary/'}], 'rate': {'limit': 2500, 'remaining': 2197, 'reset': 1553817600}, 'results': [{'annotations': {'DMS': {'lat': "37° 1' 22.42992'' N", 'lng': "106° 26' 53.79324'' W"}, 'FIPS': {'county': '08021', 'state': '08'}, 'MGRS': '13SCA7117298392', 'Maidenhead': 'DM67sa65el', 'Mercator': {'x': -11849767.869, 'y': 4416568.285}, 'OSM': {'edit_url': 'https://www.openstreetmap.org/edit?way=46576470#map=17/37.02290/-106.44828', 'url': 'https://www.openstreetmap.org/?mlat=37.02290&mlon=-106.44828#map=17/37.02290/-106.44828'}, 'callingcode': 1, 'currency': {'alternate_symbols': ['US$'], 'decimal_mark': '.', 'disambiguate_symbol': 'US$', 'html_entity': '$', 'iso_code': 'USD', 'iso_numeric': 840, 'name': 'United States Dollar', 'smallest_denomination': 1, 'subunit': 'Cent', 'subunit_to_unit': 100, 'symbol': '$', 'symbol_first': 1, 'thousands_separator': ','}, 'flag': '🇺🇸', 'geohash': '9ws69eydp2k838u22j3t', 'qibla': 34.3, 'sun': {'rise': {'apparent': 1553777700, 'astronomical': 1553772420, 'civil': 1553776140, 'nautical': 1553774340}, 'set': {'apparent': 1553736240, 'astronomical': 1553741520, 'civil': 1553737800, 'nautical': 1553739660}}, 'timezone': {'name': 'America/Denver', 'now_in_dst': 1, 'offset_sec': -21600, 'offset_string': -600, 'short_name': 'MDT'}, 'what3words': {'words': 'prestige.vortex.relies'}}, 'bounds': {'northeast': {'lat': 37.0241159, 'lng': -106.4468781}, 'southwest': {'lat': 37.0224853, 'lng': -106.449235}}, 'components': {'ISO_3166-1_alpha-2': 'US', 'ISO_3166-1_alpha-3': 'USA', '_type': 'stream', 'continent': 'North America', 'country': 'USA', 'country_code': 'us', 'county': 'Conejos County', 'state': 'Colorado', 'state_code': 'CO', 'stream': 'Cumbres Creek'}, 'confidence': 9, 'formatted': 'Cumbres Creek, Conejos County, CO, United States of America', 'geometry': {'lat': 37.0228972, 'lng': -106.4482759}}, {'annotations': {'DMS': {'lat': "37° 0' 33.04800'' N", 'lng': "106° 24' 16.12800'' W"}, 'FIPS': {'county': '08021', 'state': '08'}, 'MGRS': '13SCA7504696812', 'Maidenhead': 'DM67ta12le', 'Mercator': {'x': -11844892.532, 'y': 4414664.063}, 'OSM': {'url': 'https://www.openstreetmap.org/?mlat=37.00918&mlon=-106.40448#map=17/37.00918/-106.40448'}, 'callingcode': 1, 'currency': {'alternate_symbols': ['US$'], 'decimal_mark': '.', 'disambiguate_symbol': 'US$', 'html_entity': '$', 'iso_code': 'USD', 'iso_numeric': 840, 'name': 'United States Dollar', 'smallest_denomination': 1, 'subunit': 'Cent', 'subunit_to_unit': 100, 'symbol': '$', 'symbol_first': 1, 'thousands_separator': ','}, 'flag': '🇺🇸', 'geohash': '9ws6d9qd5gjjux8kk1bb', 'qibla': 34.34, 'sun': {'rise': {'apparent': 1553777700, 'astronomical': 1553772420, 'civil': 1553776140, 'nautical': 1553774340}, 'set': {'apparent': 1553736240, 'astronomical': 1553741520, 'civil': 1553737800, 'nautical': 1553739660}}, 'timezone': {'name': 'America/Denver', 'now_in_dst': 1, 'offset_sec': -21600, 'offset_string': -600, 'short_name': 'MDT'}, 'what3words': {'words': 'shortages.refurbish.spins'}}, 'components': {'ISO_3166-1_alpha-2': 'US', 'ISO_3166-1_alpha-3': 'USA', '_type': 'county', 'continent': 'North America', 'country': 'United States of America', 'country_code': 'us', 'county': 'Conejos County', 'state': 'Colorado', 'state_code': 'CO'}, 'confidence': 9, 'formatted': 'Conejos County, CO, United States of America', 'geometry': {'lat': 37.00918, 'lng': -106.40448}}], 'status': {'code': 200, 'message': 'OK'}, 'stay_informed': {'blog': 'https://blog.opencagedata.com', 'twitter': 'https://twitter.com/opencagedata'}, 'thanks': 'For using an OpenCage Data API', 'timestamp': {'created_http': 'Thu, 28 Mar 2019 09:37:07 GMT', 'created_unix': 1553765827}, 'total_results': 2}
# [{'index': '1', 'name': 'January', 'avgMinTemp': '-12.5', 'avgMinTemp_F': '9.4', 'absMaxTemp': '1.728903', 'absMaxTemp_F': '35.1', 'avgDailyRainfall': '1.20'}, {'index': '2', 'name': 'February', 'avgMinTemp': '-11.6', 'avgMinTemp_F': '11.1', 'absMaxTemp': '1.024107', 'absMaxTemp_F': '33.8', 'avgDailyRainfall': '1.52'}, {'index': '3', 'name': 'March', 'avgMinTemp': '-7.8', 'avgMinTemp_F': '18.0', 'absMaxTemp': '5.161516', 'absMaxTemp_F': '41.3', 'avgDailyRainfall': '0.92'}, {'index': '4', 'name': 'April', 'avgMinTemp': '-4.1', 'avgMinTemp_F': '24.7', 'absMaxTemp': '10.77203', 'absMaxTemp_F': '51.4', 'avgDailyRainfall': '1.01'}, {'index': '5', 'name': 'May', 'avgMinTemp': '0.1', 'avgMinTemp_F': '32.2', 'absMaxTemp': '18.17097', 'absMaxTemp_F': '64.7', 'avgDailyRainfall': '1.04'}, {'index': '6', 'name': 'June', 'avgMinTemp': '5.3', 'avgMinTemp_F': '41.6', 'absMaxTemp': '24.39127', 'absMaxTemp_F': '75.9', 'avgDailyRainfall': '0.83'}, {'index': '7', 'name': 'July', 'avgMinTemp': '8.3', 'avgMinTemp_F': '47.0', 'absMaxTemp': '25.63103', 'absMaxTemp_F': '78.1', 'avgDailyRainfall': '3.46'}, {'index': '8', 'name': 'August', 'avgMinTemp': '7.3', 'avgMinTemp_F': '45.2', 'absMaxTemp': '23.91984', 'absMaxTemp_F': '75.1', 'avgDailyRainfall': '2.33'}, {'index': '9', 'name': 'September', 'avgMinTemp': '4.8', 'avgMinTemp_F': '40.7', 'absMaxTemp': '20.96293', 'absMaxTemp_F': '69.7', 'avgDailyRainfall': '1.44'}, {'index': '10', 'name': 'October', 'avgMinTemp': '-0.5', 'avgMinTemp_F': '31.1', 'absMaxTemp': '13.80561', 'absMaxTemp_F': '56.9', 'avgDailyRainfall': '0.99'}, {'index': '11', 'name': 'November', 'avgMinTemp': '-6.4', 'avgMinTemp_F': '20.5', 'absMaxTemp': '7.660867', 'absMaxTemp_F': '45.8', 'avgDailyRainfall': '0.80'}, {'index': '12', 'name': 'December', 'avgMinTemp': '-11.4', 'avgMinTemp_F': '11.5', 'absMaxTemp': '2.898387', 'absMaxTemp_F': '37.2', 'avgDailyRainfall': '1.06'}]
# --------------------------------------------------
# https://api.opencagedata.com/geocode/v1/json?q=Georgetown%20Loop%20Historic%20Railroad&key=e9371220b0d64866ab25b1760944394f
# {'documentation': 'https://opencagedata.com/api', 'licenses': [{'name': 'CC-BY-SA', 'url': 'https://creativecommons.org/licenses/by-sa/3.0/'}, {'name': 'ODbL', 'url': 'https://opendatacommons.org/licenses/odbl/summary/'}], 'rate': {'limit': 2500, 'remaining': 2196, 'reset': 1553817600}, 'results': [{'annotations': {'DMS': {'lat': "39° 45' 38.37600'' N", 'lng': "76° 41' 53.88000'' W"}, 'FIPS': {'county': '42133', 'state': '42'}, 'MGRS': '18SUK5452402572', 'Maidenhead': 'FM19ps62en', 'Mercator': {'x': -8538015.701, 'y': 4803889.122}, 'OSM': {'url': 'https://www.openstreetmap.org/?mlat=39.76066&mlon=-76.69830#map=17/39.76066/-76.69830'}, 'callingcode': 1, 'currency': {'alternate_symbols': ['US$'], 'decimal_mark': '.', 'disambiguate_symbol': 'US$', 'html_entity': '$', 'iso_code': 'USD', 'iso_numeric': 840, 'name': 'United States Dollar', 'smallest_denomination': 1, 'subunit': 'Cent', 'subunit_to_unit': 100, 'symbol': '$', 'symbol_first': 1, 'thousands_separator': ','}, 'flag': '🇺🇸', 'geohash': 'dr16nwnn8h4rsbkdmpdj', 'qibla': 56.72, 'sun': {'rise': {'apparent': 1553770560, 'astronomical': 1553765040, 'civil': 1553768940, 'nautical': 1553767020}, 'set': {'apparent': 1553815620, 'astronomical': 1553734740, 'civil': 1553817240, 'nautical': 1553732760}}, 'timezone': {'name': 'America/New_York', 'now_in_dst': 1, 'offset_sec': -14400, 'offset_string': -400, 'short_name': 'EDT'}, 'what3words': {'words': 'lend.weeks.tunnel'}}, 'bounds': {'northeast': {'lat': 39.765724, 'lng': -76.68416}, 'southwest': {'lat': 39.752595, 'lng': -76.706385}}, 'components': {'ISO_3166-1_alpha-2': 'US', 'ISO_3166-1_alpha-3': 'USA', '_type': 'city', 'continent': 'North America', 'country': 'United States of America', 'country_code': 'us', 'county': 'York County', 'state': 'Pennsylvania', 'state_code': 'PA', 'town': 'Railroad'}, 'confidence': 8, 'formatted': 'Railroad, PA, United States of America', 'geometry': {'lat': 39.76066, 'lng': -76.6983}}], 'status': {'code': 200, 'message': 'OK'}, 'stay_informed': {'blog': 'https://blog.opencagedata.com', 'twitter': 'https://twitter.com/opencagedata'}, 'thanks': 'For using an OpenCage Data API', 'timestamp': {'created_http': 'Thu, 28 Mar 2019 09:37:09 GMT', 'created_unix': 1553765829}, 'total_results': 1}
# [{'index': '1', 'name': 'January', 'avgMinTemp': '-4.9', 'avgMinTemp_F': '23.1', 'absMaxTemp': '4.753807', 'absMaxTemp_F': '40.6', 'avgDailyRainfall': '1.13'}, {'index': '2', 'name': 'February', 'avgMinTemp': '-3.7', 'avgMinTemp_F': '25.3', 'absMaxTemp': '9.767107', 'absMaxTemp_F': '49.6', 'avgDailyRainfall': '1.16'}, {'index': '3', 'name': 'March', 'avgMinTemp': '0.6', 'avgMinTemp_F': '33.0', 'absMaxTemp': '15.07623', 'absMaxTemp_F': '59.1', 'avgDailyRainfall': '0.87'}, {'index': '4', 'name': 'April', 'avgMinTemp': '6.2', 'avgMinTemp_F': '43.2', 'absMaxTemp': '18.35257', 'absMaxTemp_F': '65.0', 'avgDailyRainfall': '1.00'}, {'index': '5', 'name': 'May', 'avgMinTemp': '11.9', 'avgMinTemp_F': '53.4', 'absMaxTemp': '24.50623', 'absMaxTemp_F': '76.1', 'avgDailyRainfall': '1.39'}, {'index': '6', 'name': 'June', 'avgMinTemp': '15.9', 'avgMinTemp_F': '60.6', 'absMaxTemp': '27.89107', 'absMaxTemp_F': '82.2', 'avgDailyRainfall': '1.23'}, {'index': '7', 'name': 'July', 'avgMinTemp': '18.4', 'avgMinTemp_F': '65.2', 'absMaxTemp': '30.75461', 'absMaxTemp_F': '87.4', 'avgDailyRainfall': '1.33'}, {'index': '8', 'name': 'August', 'avgMinTemp': '17.5', 'avgMinTemp_F': '63.4', 'absMaxTemp': '29.31406', 'absMaxTemp_F': '84.8', 'avgDailyRainfall': '1.42'}, {'index': '9', 'name': 'September', 'avgMinTemp': '14.1', 'avgMinTemp_F': '57.4', 'absMaxTemp': '25.77103', 'absMaxTemp_F': '78.4', 'avgDailyRainfall': '1.47'}, {'index': '10', 'name': 'October', 'avgMinTemp': '8.6', 'avgMinTemp_F': '47.5', 'absMaxTemp': '19.91413', 'absMaxTemp_F': '67.8', 'avgDailyRainfall': '1.46'}, {'index': '11', 'name': 'November', 'avgMinTemp': '2.7', 'avgMinTemp_F': '36.9', 'absMaxTemp': '14.05837', 'absMaxTemp_F': '57.3', 'avgDailyRainfall': '1.76'}, {'index': '12', 'name': 'December', 'avgMinTemp': '-0.8', 'avgMinTemp_F': '30.6', 'absMaxTemp': '12.11016', 'absMaxTemp_F': '53.8', 'avgDailyRainfall': '1.22'}]
# --------------------------------------------------
# https://api.opencagedata.com/geocode/v1/json?q=Rio%20Grande%20Scenic%20Railroad&key=e9371220b0d64866ab25b1760944394f
# {'documentation': 'https://opencagedata.com/api', 'licenses': [{'name': 'CC-BY-SA', 'url': 'https://creativecommons.org/licenses/by-sa/3.0/'}, {'name': 'ODbL', 'url': 'https://opendatacommons.org/licenses/odbl/summary/'}], 'rate': {'limit': 2500, 'remaining': 2195, 'reset': 1553817600}, 'results': [{'annotations': {'DMS': {'lat': "39° 45' 38.37600'' N", 'lng': "76° 41' 53.88000'' W"}, 'FIPS': {'county': '42133', 'state': '42'}, 'MGRS': '18SUK5452402572', 'Maidenhead': 'FM19ps62en', 'Mercator': {'x': -8538015.701, 'y': 4803889.122}, 'OSM': {'url': 'https://www.openstreetmap.org/?mlat=39.76066&mlon=-76.69830#map=17/39.76066/-76.69830'}, 'callingcode': 1, 'currency': {'alternate_symbols': ['US$'], 'decimal_mark': '.', 'disambiguate_symbol': 'US$', 'html_entity': '$', 'iso_code': 'USD', 'iso_numeric': 840, 'name': 'United States Dollar', 'smallest_denomination': 1, 'subunit': 'Cent', 'subunit_to_unit': 100, 'symbol': '$', 'symbol_first': 1, 'thousands_separator': ','}, 'flag': '🇺🇸', 'geohash': 'dr16nwnn8h4rsbkdmpdj', 'qibla': 56.72, 'sun': {'rise': {'apparent': 1553770560, 'astronomical': 1553765040, 'civil': 1553768940, 'nautical': 1553767020}, 'set': {'apparent': 1553815620, 'astronomical': 1553734740, 'civil': 1553817240, 'nautical': 1553732760}}, 'timezone': {'name': 'America/New_York', 'now_in_dst': 1, 'offset_sec': -14400, 'offset_string': -400, 'short_name': 'EDT'}, 'what3words': {'words': 'lend.weeks.tunnel'}}, 'bounds': {'northeast': {'lat': 39.765724, 'lng': -76.68416}, 'southwest': {'lat': 39.752595, 'lng': -76.706385}}, 'components': {'ISO_3166-1_alpha-2': 'US', 'ISO_3166-1_alpha-3': 'USA', '_type': 'city', 'continent': 'North America', 'country': 'United States of America', 'country_code': 'us', 'county': 'York County', 'state': 'Pennsylvania', 'state_code': 'PA', 'town': 'Railroad'}, 'confidence': 8, 'formatted': 'Railroad, PA, United States of America', 'geometry': {'lat': 39.76066, 'lng': -76.6983}}], 'status': {'code': 200, 'message': 'OK'}, 'stay_informed': {'blog': 'https://blog.opencagedata.com', 'twitter': 'https://twitter.com/opencagedata'}, 'thanks': 'For using an OpenCage Data API', 'timestamp': {'created_http': 'Thu, 28 Mar 2019 09:37:13 GMT', 'created_unix': 1553765833}, 'total_results': 1}
# [{'index': '1', 'name': 'January', 'avgMinTemp': '-4.9', 'avgMinTemp_F': '23.1', 'absMaxTemp': '4.753807', 'absMaxTemp_F': '40.6', 'avgDailyRainfall': '1.13'}, {'index': '2', 'name': 'February', 'avgMinTemp': '-3.7', 'avgMinTemp_F': '25.3', 'absMaxTemp': '9.767107', 'absMaxTemp_F': '49.6', 'avgDailyRainfall': '1.16'}, {'index': '3', 'name': 'March', 'avgMinTemp': '0.6', 'avgMinTemp_F': '33.0', 'absMaxTemp': '15.07623', 'absMaxTemp_F': '59.1', 'avgDailyRainfall': '0.87'}, {'index': '4', 'name': 'April', 'avgMinTemp': '6.2', 'avgMinTemp_F': '43.2', 'absMaxTemp': '18.35257', 'absMaxTemp_F': '65.0', 'avgDailyRainfall': '1.00'}, {'index': '5', 'name': 'May', 'avgMinTemp': '11.9', 'avgMinTemp_F': '53.4', 'absMaxTemp': '24.50623', 'absMaxTemp_F': '76.1', 'avgDailyRainfall': '1.39'}, {'index': '6', 'name': 'June', 'avgMinTemp': '15.9', 'avgMinTemp_F': '60.6', 'absMaxTemp': '27.89107', 'absMaxTemp_F': '82.2', 'avgDailyRainfall': '1.23'}, {'index': '7', 'name': 'July', 'avgMinTemp': '18.4', 'avgMinTemp_F': '65.2', 'absMaxTemp': '30.75461', 'absMaxTemp_F': '87.4', 'avgDailyRainfall': '1.33'}, {'index': '8', 'name': 'August', 'avgMinTemp': '17.5', 'avgMinTemp_F': '63.4', 'absMaxTemp': '29.31406', 'absMaxTemp_F': '84.8', 'avgDailyRainfall': '1.42'}, {'index': '9', 'name': 'September', 'avgMinTemp': '14.1', 'avgMinTemp_F': '57.4', 'absMaxTemp': '25.77103', 'absMaxTemp_F': '78.4', 'avgDailyRainfall': '1.47'}, {'index': '10', 'name': 'October', 'avgMinTemp': '8.6', 'avgMinTemp_F': '47.5', 'absMaxTemp': '19.91413', 'absMaxTemp_F': '67.8', 'avgDailyRainfall': '1.46'}, {'index': '11', 'name': 'November', 'avgMinTemp': '2.7', 'avgMinTemp_F': '36.9', 'absMaxTemp': '14.05837', 'absMaxTemp_F': '57.3', 'avgDailyRainfall': '1.76'}, {'index': '12', 'name': 'December', 'avgMinTemp': '-0.8', 'avgMinTemp_F': '30.6', 'absMaxTemp': '12.11016', 'absMaxTemp_F': '53.8', 'avgDailyRainfall': '1.22'}]
# --------------------------------------------------
# ...
# [{'index': '1', 'name': 'January', 'avgMinTemp': '-0.2', 'avgMinTemp_F': '31.6', 'absMaxTemp': '7.11871', 'absMaxTemp_F': '44.8', 'avgDailyRainfall': '0.81'}, {'index': '2', 'name': 'February', 'avgMinTemp': '0.0', 'avgMinTemp_F': '31.9', 'absMaxTemp': '11.86071', 'absMaxTemp_F': '53.3', 'avgDailyRainfall': '0.61'}, {'index': '3', 'name': 'March', 'avgMinTemp': '2.1', 'avgMinTemp_F': '35.7', 'absMaxTemp': '13.43218', 'absMaxTemp_F': '56.2', 'avgDailyRainfall': '0.65'}, {'index': '4', 'name': 'April', 'avgMinTemp': '5.1', 'avgMinTemp_F': '41.2', 'absMaxTemp': '18.03037', 'absMaxTemp_F': '64.5', 'avgDailyRainfall': '0.53'}, {'index': '5', 'name': 'May', 'avgMinTemp': '7.8', 'avgMinTemp_F': '46.1', 'absMaxTemp': '22.04481', 'absMaxTemp_F': '71.7', 'avgDailyRainfall': '0.96'}, {'index': '6', 'name': 'June', 'avgMinTemp': '10.7', 'avgMinTemp_F': '51.3', 'absMaxTemp': '22.52833', 'absMaxTemp_F': '72.6', 'avgDailyRainfall': '1.10'}, {'index': '7', 'name': 'July', 'avgMinTemp': '13.2', 'avgMinTemp_F': '55.8', 'absMaxTemp': '27.15352', 'absMaxTemp_F': '80.9', 'avgDailyRainfall': '0.96'}, {'index': '8', 'name': 'August', 'avgMinTemp': '13.3', 'avgMinTemp_F': '55.9', 'absMaxTemp': '25.22261', 'absMaxTemp_F': '77.4', 'avgDailyRainfall': '0.81'}, {'index': '9', 'name': 'September', 'avgMinTemp': '10.4', 'avgMinTemp_F': '50.8', 'absMaxTemp': '22.0425', 'absMaxTemp_F': '71.7', 'avgDailyRainfall': '0.56'}, {'index': '10', 'name': 'October', 'avgMinTemp': '7.2', 'avgMinTemp_F': '44.9', 'absMaxTemp': '17.76129', 'absMaxTemp_F': '64.0', 'avgDailyRainfall': '0.53'}, {'index': '11', 'name': 'November', 'avgMinTemp': '4.3', 'avgMinTemp_F': '39.7', 'absMaxTemp': '11.30913', 'absMaxTemp_F': '52.4', 'avgDailyRainfall': '0.68'}, {'index': '12', 'name': 'December', 'avgMinTemp': '1.4', 'avgMinTemp_F': '34.5', 'absMaxTemp': '9.358974', 'absMaxTemp_F': '48.8', 'avgDailyRainfall': '0.98'}]
# --------------------------------------------------
# https://api.opencagedata.com/geocode/v1/json?q=Estes%20Park&key=e9371220b0d64866ab25b1760944394f
# {'documentation': 'https://opencagedata.com/api', 'licenses': [{'name': 'CC-BY-SA', 'url': 'https://creativecommons.org/licenses/by-sa/3.0/'}, {'name': 'ODbL', 'url': 'https://opendatacommons.org/licenses/odbl/summary/'}], 'rate': {'limit': 2500, 'remaining': 2187, 'reset': 1553817600}, 'results': [{'annotations': {'DMS': {'lat': "40° 22' 11.15760'' N", 'lng': "105° 32' 58.88256'' W"}, 'FIPS': {'county': '08069', 'state': '08'}, 'MGRS': '13TDE5333268943', 'Maidenhead': 'DN70fi48ar', 'Mercator': {'x': -11749737.704, 'y': 4892140.075}, 'OSM': {'edit_url': 'https://www.openstreetmap.org/edit?way=33121506#map=17/40.36977/-105.54969', 'url': 'https://www.openstreetmap.org/?mlat=40.36977&mlon=-105.54969#map=17/40.36977/-105.54969'}, 'callingcode': 1, 'currency': {'alternate_symbols': ['US$'], 'decimal_mark': '.', 'disambiguate_symbol': 'US$', 'html_entity': '$', 'iso_code': 'USD', 'iso_numeric': 840, 'name': 'United States Dollar', 'smallest_denomination': 1, 'subunit': 'Cent', 'subunit_to_unit': 100, 'symbol': '$', 'symbol_first': 1, 'thousands_separator': ','}, 'flag': '🇺🇸', 'geohash': '9xhvwjj4cvz434d9rczp', 'qibla': 34.33, 'sun': {'rise': {'apparent': 1553777400, 'astronomical': 1553771880, 'civil': 1553775780, 'nautical': 1553773860}, 'set': {'apparent': 1553736120, 'astronomical': 1553741700, 'civil': 1553737800, 'nautical': 1553739720}}, 'timezone': {'name': 'America/Denver', 'now_in_dst': 1, 'offset_sec': -21600, 'offset_string': -600, 'short_name': 'MDT'}, 'what3words': {'words': 'disapprove.overtly.slam'}, 'wikidata': 'Q1010533'}, 'bounds': {'northeast': {'lat': 40.370913, 'lng': -105.547141}, 'southwest': {'lat': 40.368687, 'lng': -105.552132}}, 'components': {'ISO_3166-1_alpha-2': 'US', 'ISO_3166-1_alpha-3': 'USA', '_type': 'city', 'city': 'Estes Park', 'continent': 'North America', 'country': 'USA', 'country_code': 'us', 'county': 'Larimer County', 'state': 'Colorado', 'state_code': 'CO'}, 'confidence': 9, 'formatted': 'Estes Park, CO, United States of America', 'geometry': {'lat': 40.369766, 'lng': -105.5496896}}, {'annotations': {'DMS': {'lat': "40° 22' 37.89336'' N", 'lng': "105° 31' 23.58084'' W"}, 'FIPS': {'county': '08069', 'state': '08'}, 'MGRS': '13TDE5558469754', 'Maidenhead': 'DN70fj70fm', 'Mercator': {'x': -11746790.772, 'y': 4893221.019}, 'OSM': {'edit_url': 'https://www.openstreetmap.org/edit?relation=112474#map=17/40.37719/-105.52322', 'url': 'https://www.openstreetmap.org/?mlat=40.37719&mlon=-105.52322#map=17/40.37719/-105.52322'}, 'callingcode': 1, 'currency': {'alternate_symbols': ['US$'], 'decimal_mark': '.', 'disambiguate_symbol': 'US$', 'html_entity': '$', 'iso_code': 'USD', 'iso_numeric': 840, 'name': 'United States Dollar', 'smallest_denomination': 1, 'subunit': 'Cent', 'subunit_to_unit': 100, 'symbol': '$', 'symbol_first': 1, 'thousands_separator': ','}, 'flag': '🇺🇸', 'geohash': '9xhvwy2q4y4x9pht6swh', 'qibla': 34.35, 'sun': {'rise': {'apparent': 1553777400, 'astronomical': 1553771880, 'civil': 1553775780, 'nautical': 1553773860}, 'set': {'apparent': 1553736120, 'astronomical': 1553741700, 'civil': 1553737740, 'nautical': 1553739720}}, 'timezone': {'name': 'America/Denver', 'now_in_dst': 1, 'offset_sec': -21600, 'offset_string': -600, 'short_name': 'MDT'}, 'what3words': {'words': 'tightly.downs.funky'}, 'wikidata': 'Q1010533'}, 'bounds': {'northeast': {'lat': 40.401403, 'lng': -105.486834}, 'southwest': {'lat': 40.331145, 'lng': -105.579462}}, 'components': {'ISO_3166-1_alpha-2': 'US', 'ISO_3166-1_alpha-3': 'USA', '_type': 'city', 'city': 'Estes Park', 'continent': 'North America', 'country': 'USA', 'country_code': 'us', 'county': 'Larimer County', 'postcode': '80517', 'state': 'Colorado', 'state_code': 'CO'}, 'confidence': 7, 'formatted': 'Estes Park, CO 80517, United States of America', 'geometry': {'lat': 40.3771926, 'lng': -105.5232169}}, {'annotations': {'DMS': {'lat': "41° 44' 55.98780'' N", 'lng': "88° 10' 55.40664'' W"}, 'FIPS': {'county': '17043', 'state': '17'}, 'MGRS': '16TDM0172022570' ...
# [{'index': '1', 'name': 'January', 'avgMinTemp': '-10.6', 'avgMinTemp_F': '12.9', 'absMaxTemp': '1.329032', 'absMaxTemp_F': '34.4', 'avgDailyRainfall': '0.82'}, {'index': '2', 'name': 'February', 'avgMinTemp': '-10.7', 'avgMinTemp_F': '12.8', 'absMaxTemp': '0.8054643', 'absMaxTemp_F': '33.4', 'avgDailyRainfall': '1.12'}, {'index': '3', 'name': 'March', 'avgMinTemp': '-6.7', 'avgMinTemp_F': '19.9', 'absMaxTemp': '7.095871', 'absMaxTemp_F': '44.8', 'avgDailyRainfall': '1.22'}, {'index': '4', 'name': 'April', 'avgMinTemp': '-4.7', 'avgMinTemp_F': '23.5', 'absMaxTemp': '11.16403', 'absMaxTemp_F': '52.1', 'avgDailyRainfall': '1.87'}, {'index': '5', 'name': 'May', 'avgMinTemp': '-0.1', 'avgMinTemp_F': '31.9', 'absMaxTemp': '14.87519', 'absMaxTemp_F': '58.8', 'avgDailyRainfall': '2.61'}, {'index': '6', 'name': 'June', 'avgMinTemp': '6.4', 'avgMinTemp_F': '43.6', 'absMaxTemp': '23.41007', 'absMaxTemp_F': '74.1', 'avgDailyRainfall': '1.37'}, {'index': '7', 'name': 'July', 'avgMinTemp': '9.2', 'avgMinTemp_F': '48.5', 'absMaxTemp': '24.14723', 'absMaxTemp_F': '75.5', 'avgDailyRainfall': '2.14'}, {'index': '8', 'name': 'August', 'avgMinTemp': '8.2', 'avgMinTemp_F': '46.8', 'absMaxTemp': '23.554', 'absMaxTemp_F': '74.4', 'avgDailyRainfall': '1.39'}, {'index': '9', 'name': 'September', 'avgMinTemp': '5.4', 'avgMinTemp_F': '41.7', 'absMaxTemp': '21.5237', 'absMaxTemp_F': '70.7', 'avgDailyRainfall': '1.06'}, {'index': '10', 'name': 'October', 'avgMinTemp': '-0.9', 'avgMinTemp_F': '30.4', 'absMaxTemp': '12.54645', 'absMaxTemp_F': '54.6', 'avgDailyRainfall': '0.97'}, {'index': '11', 'name': 'November', 'avgMinTemp': '-6.2', 'avgMinTemp_F': '20.8', 'absMaxTemp': '6.633567', 'absMaxTemp_F': '43.9', 'avgDailyRainfall': '0.72'}, {'index': '12', 'name': 'December', 'avgMinTemp': '-10.9', 'avgMinTemp_F': '12.3', 'absMaxTemp': '0.7740968', 'absMaxTemp_F': '33.4', 'avgDailyRainfall': '0.73'}]
# --------------------------------------------------
# https://api.opencagedata.com/geocode/v1/json?q=Emerald%20Lake%20Trail&key=e9371220b0d64866ab25b1760944394f
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-1-db38c9eadc20> in <module>()
#     217         print(url)
#     218         http = urllib3.PoolManager()
# --> 219         response = http.request('GET', url)
#     220         soup = BeautifulSoup(response.data)
#     221         newDictionary=json.loads(soup.text)
#
# /usr/lib/python3/dist-packages/urllib3/request.py in request(self, method, url, fields, headers, **urlopen_kw)
#      64             return self.request_encode_url(method, url, fields=fields,
#      65                                            headers=headers,
# ---> 66                                            **urlopen_kw)
#      67         else:
#      68             return self.request_encode_body(method, url, fields=fields,
#
# /usr/lib/python3/dist-packages/urllib3/request.py in request_encode_url(self, method, url, fields, headers, **urlopen_kw)
#      85             url += '?' + urlencode(fields)
#      86
# ---> 87         return self.urlopen(method, url, **extra_kw)
#      88
#      89     def request_encode_body(self, method, url, fields=None, headers=None,
#
# /usr/lib/python3/dist-packages/urllib3/poolmanager.py in urlopen(self, method, url, redirect, **kw)
#     319             response = conn.urlopen(method, url, **kw)
#     320         else:
# --> 321             response = conn.urlopen(method, u.request_uri, **kw)
#     322
#     323         redirect_location = redirect and response.get_redirect_location()
#
# /usr/lib/python3/dist-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     599                                                   timeout=timeout_obj,
#     600                                                   body=body, headers=headers,
# --> 601                                                   chunked=chunked)
#     602
#     603             # If we're going to release the connection in ``finally:``, then
#
# /usr/lib/python3/dist-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     344         # Trigger any extra validation we need to do.
#     345         try:
# --> 346             self._validate_conn(conn)
#     347         except (SocketTimeout, BaseSSLError) as e:
#     348             # Py2 raises this as a BaseSSLError, Py3 raises it as socket timeout.
#
# /usr/lib/python3/dist-packages/urllib3/connectionpool.py in _validate_conn(self, conn)
#     850         # Force connect early to allow us to validate the connection.
#     851         if not getattr(conn, 'sock', None):  # AppEngine might not have  `.sock`
# --> 852             conn.connect()
#     853
#     854         if not conn.is_verified:
#
# /usr/lib/python3/dist-packages/urllib3/connection.py in connect(self)
#     324             ca_cert_dir=self.ca_cert_dir,
#     325             server_hostname=hostname,
# --> 326             ssl_context=context)
#     327
#     328         if self.assert_fingerprint:
#
# /usr/lib/python3/dist-packages/urllib3/util/ssl_.py in ssl_wrap_socket(sock, keyfile, certfile, cert_reqs, ca_certs, server_hostname, ssl_version, ciphers, ssl_context, ca_cert_dir)
#     327         context.load_cert_chain(certfile, keyfile)
#     328     if HAS_SNI:  # Platform-specific: OpenSSL with enabled SNI
# --> 329         return context.wrap_socket(sock, server_hostname=server_hostname)
#     330
#     331     warnings.warn(
#
# /usr/lib/python3.6/ssl.py in wrap_socket(self, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, session)
#     405                          suppress_ragged_eofs=suppress_ragged_eofs,
#     406                          server_hostname=server_hostname,
# --> 407                          _context=self, _session=session)
#     408
#     409     def wrap_bio(self, incoming, outgoing, server_side=False,
#
# /usr/lib/python3.6/ssl.py in __init__(self, sock, keyfile, certfile, server_side, cert_reqs, ssl_version, ca_certs, do_handshake_on_connect, family, type, proto, fileno, suppress_ragged_eofs, npn_protocols, ciphers, server_hostname, _context, _session)
#     815                         # non-blocking
#     816                         raise ValueError("do_handshake_on_connect should not be specified for non-blocking sockets")
# --> 817                     self.do_handshake()
#     818
#     819             except (OSError, ValueError):
#
# /usr/lib/python3.6/ssl.py in do_handshake(self, block)
#    1075             if timeout == 0.0 and block:
#    1076                 self.settimeout(None)
# -> 1077             self._sslobj.do_handshake()
#    1078         finally:
#    1079             self.settimeout(timeout)
#
# /usr/lib/python3.6/ssl.py in do_handshake(self)
#     687     def do_handshake(self):
#     688         """Start the SSL/TLS handshake."""
# --> 689         self._sslobj.do_handshake()
#     690         if self.context.check_hostname:
#     691             if not self.server_hostname:
#
# KeyboardInterrupt:
